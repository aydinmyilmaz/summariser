# %%
import streamlit as st
from langchain.chat_models import ChatAnthropic
from langchain.prompts import ChatPromptTemplate
from langchain.output_parsers import PydanticOutputParser
from langchain.prompts import HumanMessagePromptTemplate, SystemMessagePromptTemplate
from langchain.schema import HumanMessage, SystemMessage
from pydantic import BaseModel, Field
from typing import List, Optional
import os
from pathlib import Path

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain.chains import LLMChain

# %%
from langchain.chat_models import ChatOpenAI  # Changed this import
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain_core.output_parsers import StrOutputParser
from dotenv import load_dotenv
import os

# Load API key
load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")

# Create an instance of ChatOpenAI instead of OpenAI
llm = ChatOpenAI(
    api_key=api_key,
    model="gpt-4o-mini",  # or "gpt-3.5-turbo" - remove "o-mini" suffix
    temperature=0.1
)

main_prompt = #s
general_guideline =
section_guidelines =
# Define the prompt template
prompt = PromptTemplate(
    input_variables=["main_prompt", "general_guideline", "section_guidelines", "input_text"],
    template="{main_prompt}\n\n Guidelines:\n\n{{general_guideline}\n\n{section_guidelines}\n\n \n\n{input_text}"
)

# Create the chain using the new syntax
chain = prompt | llm | StrOutputParser()

# Run the chain with user input
user_input = "Provide an overview of the latest trends in Artificial Intelligence."
summary = chain.invoke({"input_text": user_input})
print("AI Overview:", summary)
# Out:
# AI Overview: The latest trends in Artificial Intelligence (AI) include advancements in generative AI, which enables the creation of content such as text, images, and music. There is also a growing focus on ethical AI, emphasizing fairness, transparency, and accountability in AI systems. Additionally, AI is increasingly being integrated into various industries, enhancing automation and decision-making processes. The rise of AI-powered tools for data analysis and predictive modeling is notable, as is the development of AI in natural language processing, improving human-computer interaction. Furthermore, there is a trend towards more collaborative AI, where humans and machines work together to achieve better outcomes.

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain_core.output_parsers import StrOutputParser
from dotenv import load_dotenv
import os

# Load API key
load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")

def read_file_content(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            return file.read().strip()
    except FileNotFoundError:
        print(f"Error: File not found at {file_path}")
        return ""
    except Exception as e:
        print(f"Error reading file {file_path}: {str(e)}")
        return ""

# Load prompts and guidelines from files
base_dir = os.path.dirname(os.path.abspath('__file__'))
analyze_prompt = read_file_content(os.path.join(base_dir, 'prompts', 'analyze_prompt.txt'))
correction_prompt = read_file_content(os.path.join(base_dir, 'prompts', 'correction_prompt.txt'))
general_guideline = read_file_content(os.path.join(base_dir, 'guidelines', '0_general_guideline.txt'))
description_guideline = read_file_content(os.path.join(base_dir, 'guidelines', '1_description_guideline.txt'))
objective_guideline = read_file_content(os.path.join(base_dir, 'guidelines', '2_objective_guideline.txt'))

# Combine section guidelines
section_guidelines = f"""
{description_guideline}

{objective_guideline}
"""


# Create an instance of ChatOpenAI
llm = ChatOpenAI(
    api_key=api_key,
    model="gpt-4o",
    temperature=0.3
)

# %%
executive_summary_section = """The GenAI-Powered Customer Service Chatbot Implementation project was initiated in April 2024 to improve customer experience and operational efficiency across digital support channels. This initiative aligns with the company’s strategic objectives to streamline customer service processes and enhance customer satisfaction through advanced AI-driven solutions. The pilot phase was successfully conducted over three months, covering key regions including the United Kingdom, Germany, and France, and has shown substantial improvement in handling routine inquiries, freeing human agents to address more complex issues. Since its launch, the chatbot has managed 150,000 customer interactions, achieving a first-contact resolution rate of 85% and reducing response time by 60%. Customer satisfaction scores in pilot regions improved by an average of 20%, with notable increases in Net Promoter Score (NPS) from 45 to 55 in the UK, from 50 to 58 in Germany, and from 47 to 53 in France. The pilot results highlight the chatbot’s potential to standardize responses and maintain high service quality while reducing operational costs. This agenda item addresses the need to expand the chatbot's capabilities to additional languages and service areas, particularly to support our expanding markets in Southern Europe and Asia. With an increasing number of customer inquiries driven by our product portfolio’s growth, the GenAI chatbot will play a pivotal role in ensuring service consistency and scalability. As customer expectations continue to rise, implementing an efficient, AI-powered support solution will be essential to maintain competitiveness and uphold our brand reputation in global markets. """

# %%
# Define the prompt template with multiline string
analyze_prompt_template = PromptTemplate(
    input_variables=[
        "analyze_prompt",
        "general_guideline",
        "description_guideline",
        "executive_summary_section"],
    template="""
{analyze_prompt}

Guidelines:
-----------
{general_guideline}

Section-Specific Guidelines:
---------------------------
{description_guideline}

Executive Summary Section:
-----------
{executive_summary_section}
"""
)

# Create the chain using the new syntax
chain = analyze_prompt_template | llm | StrOutputParser()

# Invoke the chain with all parameters
analysis_result = chain.invoke({
    "analyze_prompt": analyze_prompt,
    "general_guideline": general_guideline,
    "description_guideline": description_guideline,
    "executive_summary_section": executive_summary_section
})

print("-" * 80)
print(analysis_result)
print("-" * 80)

# %%
# Invoke the chain with all parameters
analysis_result = chain.invoke({
    "analyze_prompt": analyze_prompt,
    "general_guideline": general_guideline,
    "description_guideline": description_guideline,
    "executive_summary_section": executive_summary_section
})

print("-" * 80)
print(analysis_result)
print("-" * 80)
# Out:
# --------------------------------------------------------------------------------
# **Executive Summary Review Report**
#
# ---
#
# **1. Missing Required Fields**
#
# - **Formatting Elements**:
#   - **Font**: The specified font is "XXX Office," but the current document does not specify if this requirement is met. Ensure the font matches the guideline.
#   - **Font Size**: Verify that the font size is set to 10.5.
#   - **Margins**: Confirm that pre-set margins are used.
#   - **Language**: Ensure the document is in British English. For instance, check for American English spellings and adjust accordingly.
#
# - **Header Information**:
#   - **Date**: Missing. Include the date of the document preparation.
#   - **Topic Name**: Present.
#   - **Owner**: Missing. Identify the document owner or responsible person.
#   - **Time Estimation**: Missing. Include an estimated time for reading or reviewing the document.
#
# ---
#
# **2. Structural Compliance**
#
# - **Length Restrictions**:
# ...

# %%
# Define the prompt template with multiline string
correction_prompt = PromptTemplate(
    input_variables=[
        "correction_prompt",
        "analysis_result",
        "executive_summary_section"],
    template="""
{correction_prompt}

Anlysis Report:
---------------------------
{analysis_result}

Executive Summary to Make Corrections:
-----------
{executive_summary_section}

Corrected Executive Summary:
-----------

"""
)

# Create the chain using the new syntax
chain = correction_prompt | llm | StrOutputParser()

# %%
corrected_result = chain.invoke({
    "correction_prompt": correction_prompt,
    "analysis_result": analysis_result,
    "executive_summary_section": executive_summary_section
})

print("-" * 80)
print(corrected_result)
print("-" * 80)
# Out:
# --------------------------------------------------------------------------------
# **Corrected Executive Summary:**
#
# ...
